# %% [markdown]
# # Titanic - EDA To prediction(DieTanic)
# - 원본 노트북 : https://www.kaggle.com/ash316/eda-to-prediction-dietanic
# - 모델링 전까지, 즉 데이터 전처리 + 피쳐 엔지니어링까지만 진행

# %% [markdown]
# # Part1: Exploratory Data Analysis (EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import os
import warnings

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#결측치 확인
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Target - Survived

# %%
f, ax = plt.subplots(1,2, figsize = (18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1], autopct = '%1.1f%%', ax = ax[0], shadow = True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')

sns.countplot('Survived', data=data, ax= ax[1])
ax[1].set_title('Survived')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - 총 승객 중 38.4%만 생존했음을 알 수 있음.

# %% [markdown]
# ## Categorical Feature

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize=(18,8))
data[['Sex', 'Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived by Sex')

sns.countplot('Sex', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - 여성의 생존율이 높은 것을 알 수 있음.

# %% [markdown]
# ## Pclass

# %%
pd.crosstab(data.Pclass, data.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_bcea5_row0_col0,#T_bcea5_row1_col1,#T_bcea5_row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_bcea5_row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_bcea5_row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_bcea5_row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_bcea5_row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_bcea5_row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_bcea5_row2_col2{
#             background-color:  #90c866;
#             color:  #000000;
#         }#T_bcea5_row3_col0,#T_bcea5_row3_col1,#T_bcea5_row3_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_bcea5_" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bcea5_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_bcea5_row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_bcea5_row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_bcea5_row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_bcea5_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_bcea5_row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_bcea5_row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_bcea5_row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_bcea5_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_bcea5_row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_bcea5_row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_bcea5_row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_bcea5_level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_bcea5_row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_bcea5_row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_bcea5_row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f, ax = plt.subplots(1, 2, figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'], ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')

sns.countplot('Pclass', hue='Survived', data=data, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - Pclass 등급이 높을 수록 생존율이 높음을 알 수 있음.
# - Sex와 Pclass를 함께 고려하여 생존율을 분석 해 볼 것.

# %%
pd.crosstab([data.Sex, data.Survived], data.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_e2e55_row0_col0,#T_e2e55_row0_col1,#T_e2e55_row0_col3,#T_e2e55_row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_e2e55_row0_col2,#T_e2e55_row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_e2e55_row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_e2e55_row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_e2e55_row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_e2e55_row2_col0{
#             background-color:  #a7d366;
#             color:  #000000;
#         }#T_e2e55_row2_col1,#T_e2e55_row2_col3{
#             background-color:  #85c266;
#             color:  #000000;
#         }#T_e2e55_row2_col2{
#             background-color:  #6eb666;
#             color:  #000000;
#         }#T_e2e55_row3_col0{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_e2e55_row3_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_e2e55_row3_col3{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_e2e55_row4_col0,#T_e2e55_row4_col1,#T_e2e55_row4_col2,#T_e2e55_row4_col3{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_e2e55_" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e2e55_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#                         <th id="T_e2e55_level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_e2e55_row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_e2e55_row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_e2e55_row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_e2e55_row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_e2e55_level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_e2e55_row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_e2e55_row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_e2e55_row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_e2e55_row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_e2e55_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#                         <th id="T_e2e55_level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_e2e55_row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_e2e55_row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_e2e55_row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_e2e55_row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_e2e55_level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_e2e55_row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_e2e55_row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_e2e55_row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_e2e55_row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_e2e55_level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_e2e55_level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_e2e55_row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_e2e55_row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_e2e55_row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_e2e55_row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=data)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - 시본에서 그래프는 대부분 다 오차범위랑 함께 시각화 됨.
# - 위의 그래프에서 세로 줄도 오차범위임.
# - 위의 결과를 통해 Pclass1의 여성 대부분이 생존한 것을 알 수 있음.

# %% [markdown]
# ## Age

# %%
#최고령 나이와 중간 나이, 평균 나이를 알아봄.
print(f"Oldest Passenger was of: {data['Age'].max()} Years")
print(f"Oldest Passenger was of: {data['Age'].min()} Years")
print(f"Oldest Passenger was of: {data['Age'].mean()} Years")
# Out:
# Oldest Passenger was of: 80.0 Years
# Oldest Passenger was of: 0.42 Years
# Oldest Passenger was of: 29.69911764705882 Years

# %%
f, ax = plt.subplots(1, 2, figsize=(18,8))
sns.violinplot("Pclass", "Age", hue="Survived", data=data, split=True, ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))

sns.violinplot("Sex", "Age", hue="Survived", data=data, split=True, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - Pclass가 낮을수록 아동 수는 증가하고, 10세 미만 아동의 생존율은 Pclass에 관계 없이 높은 편이며 Pclass 1의 20-50세 승객은 생존 가능성이 높으며 여성의 경우 훨씬 더 높다.

# %% [markdown]
# ## NaN Ages
# - Age에는 결측치가 있으며 이를 평균 나이로 채우는 것 보다 Mr,Mrs 등의 접두어로 승객을 그룹화하여 각 그룹별 평균 나이로 채울 것.

# %%
#이름에서 접두어 추출
data['Initial'] = 0
for i in data:
    data['Initial'] = data.Name.str.extract('([A-Za-z]+)\.')

# %%
pd.crosstab(data.Initial, data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_c21e6_row0_col0,#T_c21e6_row0_col1,#T_c21e6_row0_col3,#T_c21e6_row0_col4,#T_c21e6_row0_col5,#T_c21e6_row0_col7,#T_c21e6_row0_col8,#T_c21e6_row0_col12,#T_c21e6_row0_col15,#T_c21e6_row0_col16,#T_c21e6_row1_col2,#T_c21e6_row1_col6,#T_c21e6_row1_col9,#T_c21e6_row1_col10,#T_c21e6_row1_col11,#T_c21e6_row1_col13,#T_c21e6_row1_col14{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_c21e6_row0_col2,#T_c21e6_row0_col6,#T_c21e6_row0_col9,#T_c21e6_row0_col10,#T_c21e6_row0_col11,#T_c21e6_row0_col13,#T_c21e6_row0_col14,#T_c21e6_row1_col0,#T_c21e6_row1_col1,#T_c21e6_row1_col3,#T_c21e6_row1_col4,#T_c21e6_row1_col5,#T_c21e6_row1_col7,#T_c21e6_row1_col8,#T_c21e6_row1_col12,#T_c21e6_row1_col15,#T_c21e6_row1_col16{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_c21e6_" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c21e6_level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_c21e6_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_c21e6_row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_c21e6_row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_c21e6_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_c21e6_row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_c21e6_row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_c21e6_row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_c21e6_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_c21e6_row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_c21e6_row0_col9" class="data row0 col9" >182</td>
#                         <td id="T_c21e6_row0_col10" class="data row0 col10" >2</td>
#                         <td id="T_c21e6_row0_col11" class="data row0 col11" >1</td>
#                         <td id="T_c21e6_row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_c21e6_row0_col13" class="data row0 col13" >125</td>
#                         <td id="T_c21e6_row0_col14" class="data row0 col14" >1</td>
#                         <td id="T_c21e6_row0_col15" class="data row0 col15" >0</td>
#                         <td id="T_c21e6_row0_col16" class="data row0 col16" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c21e6_level0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_c21e6_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_c21e6_row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_c21e6_row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_c21e6_row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_c21e6_row1_col4" class="data row1 col4" >6</td>
#                         <td id="T_c21e6_row1_col5" class="data row1 col5" >1</td>
#                         <td id="T_c21e6_row1_col6" class="data row1 col6" >0</td>
#                         <td id="T_c21e6_row1_col7" class="data row1 col7" >2</td>
#                         <td id="T_c21e6_row1_col8" class="data row1 col8" >40</td>
#                         <td id="T_c21e6_row1_col9" class="data row1 col9" >0</td>
#                         <td id="T_c21e6_row1_col10" class="data row1 col10" >0</td>
#                         <td id="T_c21e6_row1_col11" class="data row1 col11" >0</td>
#                         <td id="T_c21e6_row1_col12" class="data row1 col12" >517</td>
#                         <td id="T_c21e6_row1_col13" class="data row1 col13" >0</td>
#                         <td id="T_c21e6_row1_col14" class="data row1 col14" >0</td>
#                         <td id="T_c21e6_row1_col15" class="data row1 col15" >6</td>
#                         <td id="T_c21e6_row1_col16" class="data row1 col16" >1</td>
#             </tr>
#     </tbody></table>

# %%
#일반적인 접두어로 대체
data['Initial'].replace(
    ['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'], 
    ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'], 
    inplace=True)

# %%
#접두어 그룹별 평균 나이
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
#그룹별 평균 나이를 반올림해서 결측치 채우기
data.loc[(data.Age.isnull()) & (data.Initial=='Master'), 'Age'] = 5
data.loc[(data.Age.isnull()) & (data.Initial=='Miss'), 'Age'] = 22
data.loc[(data.Age.isnull()) & (data.Initial=='Mr'), 'Age'] = 33
data.loc[(data.Age.isnull()) & (data.Initial=='Mrs'), 'Age'] = 36
data.loc[(data.Age.isnull()) & (data.Initial=='Other'), 'Age'] = 46

# %%
#결측치 한번 더 확인
data.Age.isnull().any()
# Out:
# False

# %%
f, ax = plt.subplots(1, 2, figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0], bins=20, color='red', edgecolor='black')
ax[0].set_title('Not Survived')
ax[0].set_xticks(list(range(0, 85, 5)))

data[data['Survived']==1].Age.plot.hist(ax=ax[1], bins=20, color='green', edgecolor='black')
ax[1].set_title('Survived')
ax[1].set_xticks(list(range(0, 85, 5)))
plt.show()

# %%
sns.factorplot('Pclass', 'Survived', col='Initial', data=data)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - 여성과 아동의 생존율이 높은 것을 보아 Pclass와 관계없이 우선으로 구조된 것으로 파악됨.

# %% [markdown]
# ## Embarked

# %%
pd.crosstab([data.Embarked, data.Pclass], [data.Sex, data.Survived], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_e6744_row0_col0,#T_e6744_row1_col2{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_e6744_row0_col1{
#             background-color:  #d2e866;
#             color:  #000000;
#         }#T_e6744_row0_col2{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_e6744_row0_col3{
#             background-color:  #d8ec66;
#             color:  #000000;
#         }#T_e6744_row0_col4,#T_e6744_row2_col3{
#             background-color:  #e8f466;
#             color:  #000000;
#         }#T_e6744_row1_col0,#T_e6744_row3_col0,#T_e6744_row3_col1,#T_e6744_row3_col2,#T_e6744_row3_col3,#T_e6744_row3_col4,#T_e6744_row4_col0,#T_e6744_row4_col2,#T_e6744_row4_col3,#T_e6744_row4_col4{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_e6744_row1_col1,#T_e6744_row6_col0{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_e6744_row1_col3,#T_e6744_row1_col4{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_e6744_row2_col0,#T_e6744_row5_col1{
#             background-color:  #e6f266;
#             color:  #000000;
#         }#T_e6744_row2_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_e6744_row2_col2{
#             background-color:  #eef666;
#             color:  #000000;
#         }#T_e6744_row2_col4,#T_e6744_row7_col0{
#             background-color:  #edf666;
#             color:  #000000;
#         }#T_e6744_row4_col1{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_e6744_row5_col0{
#             background-color:  #e3f166;
#             color:  #000000;
#         }#T_e6744_row5_col2{
#             background-color:  #ecf666;
#             color:  #000000;
#         }#T_e6744_row5_col3{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_e6744_row5_col4{
#             background-color:  #ebf566;
#             color:  #000000;
#         }#T_e6744_row6_col1{
#             background-color:  #cde666;
#             color:  #000000;
#         }#T_e6744_row6_col2{
#             background-color:  #e4f266;
#             color:  #000000;
#         }#T_e6744_row6_col3{
#             background-color:  #bede66;
#             color:  #000000;
#         }#T_e6744_row6_col4{
#             background-color:  #dbed66;
#             color:  #000000;
#         }#T_e6744_row7_col1{
#             background-color:  #bdde66;
#             color:  #000000;
#         }#T_e6744_row7_col2{
#             background-color:  #d3e966;
#             color:  #000000;
#         }#T_e6744_row7_col3,#T_e6744_row8_col1{
#             background-color:  #dcee66;
#             color:  #000000;
#         }#T_e6744_row7_col4{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_e6744_row8_col0{
#             background-color:  #52a866;
#             color:  #000000;
#         }#T_e6744_row8_col2{
#             background-color:  #81c066;
#             color:  #000000;
#         }#T_e6744_row8_col3{
#             background-color:  #b0d866;
#             color:  #000000;
#         }#T_e6744_row8_col4{
#             background-color:  #9acc66;
#             color:  #000000;
#         }#T_e6744_row9_col0,#T_e6744_row9_col1,#T_e6744_row9_col2,#T_e6744_row9_col3,#T_e6744_row9_col4{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_e6744_" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan="2">female</th>        <th class="col_heading level0 col2" colspan="2">male</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Survived</th>        <th class="col_heading level1 col0" >0</th>        <th class="col_heading level1 col1" >1</th>        <th class="col_heading level1 col2" >0</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" ></th>    </tr>    <tr>        <th class="index_name level0" >Embarked</th>        <th class="index_name level1" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e6744_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#                         <th id="T_e6744_level1_row0" class="row_heading level1 row0" >1</th>
#                         <td id="T_e6744_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_e6744_row0_col1" class="data row0 col1" >42</td>
#                         <td id="T_e6744_row0_col2" class="data row0 col2" >25</td>
#                         <td id="T_e6744_row0_col3" class="data row0 col3" >17</td>
#                         <td id="T_e6744_row0_col4" class="data row0 col4" >85</td>
#             </tr>
#             <tr>
#                                 <th id="T_e6744_level1_row1" class="row_heading level1 row1" >2</th>
#                         <td id="T_e6744_row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_e6744_row1_col1" class="data row1 col1" >7</td>
#                         <td id="T_e6744_row1_col2" class="data row1 col2" >8</td>
#                         <td id="T_e6744_row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_e6744_row1_col4" class="data row1 col4" >17</td>
#             </tr>
#             <tr>
#                                 <th id="T_e6744_level1_row2" class="row_heading level1 row2" >3</th>
#                         <td id="T_e6744_row2_col0" class="data row2 col0" >8</td>
#                         <td id="T_e6744_row2_col1" class="data row2 col1" >15</td>
#                         <td id="T_e6744_row2_col2" class="data row2 col2" >33</td>
#                         <td id="T_e6744_row2_col3" class="data row2 col3" >10</td>
#                         <td id="T_e6744_row2_col4" class="data row2 col4" >66</td>
#             </tr>
#             <tr>
#                         <th id="T_e6744_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#                         <th id="T_e6744_level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_e6744_row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_e6744_row3_col1" class="data row3 col1" >1</td>
#                         <td id="T_e6744_row3_col2" class="data row3 col2" >1</td>
#                         <td id="T_e6744_row3_col3" class="data row3 col3" >0</td>
#                         <td id="T_e6744_row3_col4" class="data row3 col4" >2</td>
#             </tr>
#             <tr>
#                                 <th id="T_e6744_level1_row4" class="row_heading level1 row4" >2</th>
#                         <td id="T_e6744_row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_e6744_row4_col1" class="data row4 col1" >2</td>
#                         <td id="T_e6744_row4_col2" class="data row4 col2" >1</td>
#                         <td id="T_e6744_row4_col3" class="data row4 col3" >0</td>
#                         <td id="T_e6744_row4_col4" class="data row4 col4" >3</td>
#             </tr>
#             <tr>
#                                 <th id="T_e6744_level1_row5" class="row_heading level1 row5" >3</th>
#                         <td id="T_e6744_row5_col0" class="data row5 col0" >9</td>
#                         <td id="T_e6744_row5_col1" class="data row5 col1" >24</td>
#                         <td id="T_e6744_row5_col2" class="data row5 col2" >36</td>
#                         <td id="T_e6744_row5_col3" class="data row5 col3" >3</td>
#                         <td id="T_e6744_row5_col4" class="data row5 col4" >72</td>
#             </tr>
#             <tr>
#                         <th id="T_e6744_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#                         <th id="T_e6744_level1_row6" class="row_heading level1 ro

# %%
sns.factorplot('Embarked', 'Survived', data=data)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f, ax = plt.subplots(2, 2, figsize=(20,15))
sns.countplot('Embarked', data=data, ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')

sns.countplot('Embarked', hue='Sex', data=data, ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')

sns.countplot('Embarked', hue='Survived', data=data, ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')

sns.countplot('Embarked', hue='Pclass', data=data, ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - S 항구에서 가장 많은 승객이 탑승했고, Pclass 3의 비율이 높아 사망자의 비율도 높은 것을 알 수 있음.
# - C 항구에서 탑승한 승객 중 상당 수가 생존했고, Pclass 1, 2의 비율이 높기 때문인 것으로 추정된다.
# - Q 항구의 승객은 대부분 Pclass 3이다

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', col='Embarked', data=data)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - S 항구의 탑승객은 Pclass 3이 많아서 남녀 모두 생존율이 낮은 편이다.
# - Q 항구의 탑승객은 대부분 Pclass 3이어서 남성의 생존율이 특히 낮다.

# %% [markdown]
# ## Nan Embarked
# - Embarked는 결측치가 2개뿐이므로 승객이 가장 많이 탑승한 S 항구로 결측치를 채운다.

# %%
data['Embarked'].fillna('S', inplace=True)

# %%
#결측치 한번 더 확인
data.Embarked.isnull().any()
# Out:
# False

# %% [markdown]
# ## SibSp - Discrete Feature
# - Sibling = brother, sister, stepbrother, stepsister
# - Spouse = husband, wife

# %%
pd.crosstab(data.SibSp, data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_33420_row0_col0,#T_33420_row0_col1{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_33420_row1_col0{
#             background-color:  #c4e266;
#             color:  #000000;
#         }#T_33420_row1_col1{
#             background-color:  #77bb66;
#             color:  #000000;
#         }#T_33420_row2_col0,#T_33420_row4_col0{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_33420_row2_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_33420_row3_col0,#T_33420_row3_col1{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_33420_row4_col1{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_33420_row5_col0,#T_33420_row5_col1,#T_33420_row6_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_33420_row6_col0{
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_33420_" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_33420_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_33420_row0_col0" class="data row0 col0" >398</td>
#                         <td id="T_33420_row0_col1" class="data row0 col1" >210</td>
#             </tr>
#             <tr>
#                         <th id="T_33420_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_33420_row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_33420_row1_col1" class="data row1 col1" >112</td>
#             </tr>
#             <tr>
#                         <th id="T_33420_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_33420_row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_33420_row2_col1" class="data row2 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_33420_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_33420_row3_col0" class="data row3 col0" >12</td>
#                         <td id="T_33420_row3_col1" class="data row3 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_33420_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_33420_row4_col0" class="data row4 col0" >15</td>
#                         <td id="T_33420_row4_col1" class="data row4 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_33420_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_33420_row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_33420_row5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_33420_level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_33420_row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_33420_row6_col1" class="data row6 col1" >0</td>
#             </tr>
#     </tbody></table>

# %%
sns.barplot('SibSp', 'Survived', data=data)
plt.title('SibSp vs Survived')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.crosstab(data.SibSp, data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_76013_row0_col0,#T_76013_row0_col1,#T_76013_row0_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_76013_row1_col0{
#             background-color:  #7bbd66;
#             color:  #000000;
#         }#T_76013_row1_col1{
#             background-color:  #8ac466;
#             color:  #000000;
#         }#T_76013_row1_col2{
#             background-color:  #c6e266;
#             color:  #000000;
#         }#T_76013_row2_col0,#T_76013_row4_col2{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_76013_row2_col1{
#             background-color:  #eef666;
#             color:  #000000;
#         }#T_76013_row2_col2{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_76013_row3_col0,#T_76013_row3_col2{
#             background-color:  #fafc66;
#             color:  #000000;
#         }#T_76013_row3_col1{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }#T_76013_row4_col0,#T_76013_row4_col1,#T_76013_row5_col0,#T_76013_row5_col1,#T_76013_row5_col2,#T_76013_row6_col0,#T_76013_row6_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_76013_row6_col2{
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_76013_" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76013_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_76013_row0_col0" class="data row0 col0" >137</td>
#                         <td id="T_76013_row0_col1" class="data row0 col1" >120</td>
#                         <td id="T_76013_row0_col2" class="data row0 col2" >351</td>
#             </tr>
#             <tr>
#                         <th id="T_76013_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_76013_row1_col0" class="data row1 col0" >71</td>
#                         <td id="T_76013_row1_col1" class="data row1 col1" >55</td>
#                         <td id="T_76013_row1_col2" class="data row1 col2" >83</td>
#             </tr>
#             <tr>
#                         <th id="T_76013_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_76013_row2_col0" class="data row2 col0" >5</td>
#                         <td id="T_76013_row2_col1" class="data row2 col1" >8</td>
#                         <td id="T_76013_row2_col2" class="data row2 col2" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_76013_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_76013_row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_76013_row3_col1" class="data row3 col1" >1</td>
#                         <td id="T_76013_row3_col2" class="data row3 col2" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_76013_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_76013_row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_76013_row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_76013_row4_col2" class="data row4 col2" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_76013_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_76013_row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_76013_row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_76013_row5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_76013_level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_76013_row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_76013_row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_76013_row6_col2" class="data row6 col2" >7</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - SibSp가 많을수록 생존율이 감소하며 SibSp가 5명 이상인 사람들은 모두 사망했다.
# - SibSp가 4명 이상인 경우는 모두 Pclass 3에 있으므로 Pclass의 영향인 것으로 파악됨.

# %% [markdown]
# ## Parch

# %%
sns.barplot('Parch', 'Survived', data=data)
plt.title('Parch vs Survived')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.crosstab(data.Parch, data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_467f6_row0_col0,#T_467f6_row0_col1,#T_467f6_row0_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_467f6_row1_col0{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_467f6_row1_col1{
#             background-color:  #c2e066;
#             color:  #000000;
#         }#T_467f6_row1_col2{
#             background-color:  #dbed66;
#             color:  #000000;
#         }#T_467f6_row2_col0{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_467f6_row2_col1{
#             background-color:  #e1f066;
#             color:  #000000;
#         }#T_467f6_row2_col2{
#             background-color:  #e3f166;
#             color:  #000000;
#         }#T_467f6_row3_col0,#T_467f6_row4_col1,#T_467f6_row5_col0,#T_467f6_row5_col1,#T_467f6_row6_col0,#T_467f6_row6_col1,#T_467f6_row6_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_467f6_row3_col1{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_467f6_row3_col2,#T_467f6_row4_col0,#T_467f6_row4_col2{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_467f6_row5_col2{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }</style><table id="T_467f6_" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >Parch</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_467f6_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_467f6_row0_col0" class="data row0 col0" >163</td>
#                         <td id="T_467f6_row0_col1" class="data row0 col1" >134</td>
#                         <td id="T_467f6_row0_col2" class="data row0 col2" >381</td>
#             </tr>
#             <tr>
#                         <th id="T_467f6_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_467f6_row1_col0" class="data row1 col0" >31</td>
#                         <td id="T_467f6_row1_col1" class="data row1 col1" >32</td>
#                         <td id="T_467f6_row1_col2" class="data row1 col2" >55</td>
#             </tr>
#             <tr>
#                         <th id="T_467f6_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_467f6_row2_col0" class="data row2 col0" >21</td>
#                         <td id="T_467f6_row2_col1" class="data row2 col1" >16</td>
#                         <td id="T_467f6_row2_col2" class="data row2 col2" >43</td>
#             </tr>
#             <tr>
#                         <th id="T_467f6_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_467f6_row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_467f6_row3_col1" class="data row3 col1" >2</td>
#                         <td id="T_467f6_row3_col2" class="data row3 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_467f6_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_467f6_row4_col0" class="data row4 col0" >1</td>
#                         <td id="T_467f6_row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_467f6_row4_col2" class="data row4 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_467f6_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_467f6_row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_467f6_row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_467f6_row5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_467f6_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_467f6_row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_467f6_row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_467f6_row6_col2" class="data row6 col2" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - 대가족은 주로 Pclass 3에 있고 생존율이 낮은 것을 알 수 있다.

# %% [markdown]
# ## Fare

# %%
print('Highest Fare was:', data['Fare'].max())
print('Lowest Fare was:', data['Fare'].min())
print('Average Fare was:', data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %%
f, ax = plt.subplots(1, 3, figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare, ax=ax[0])
ax[0].set_title('Fares in Pclass 1')

sns.distplot(data[data['Pclass']==2].Fare, ax=ax[1])
ax[1].set_title('Fares in Pclass 2')

sns.distplot(data[data['Pclass']==3].Fare, ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Correlation Between The Features

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', linewidths=0.2)
plt.show()

# %% [markdown]
# - feature들 간의 상관관계가 높지 않으므로 다중공선성이 나타나지 않을 것을 판단할 수 있음.

# %% [markdown]
# # Part2: Feature Engineering and Data Cleaning¶

# %% [markdown]
# ## Age_band
# - 연속형 변수인 Age를 구간을 나누어 범주형 변수로 변환한다.
# - 승객의 최고 연령이 80세였으므로 0-80의 범위를 5개의 bin으로 나누면 크기가 16(80/5=16)인 bin이 만들어진다.

# %%
data['Age_band'] = 0
data.loc[data['Age'] <= 16, 'Age_band'] = 0
data.loc[(data['Age'] > 16) & (data['Age'] <= 32), 'Age_band'] = 1
data.loc[(data['Age'] > 32) & (data['Age'] <= 48), 'Age_band'] = 2
data.loc[(data['Age'] > 48) & (data['Age'] <= 64), 'Age_band'] = 3
data.loc[data['Age'] > 64,'Age_band'] = 4
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Initial  Age_band
# 0      0  A/5 21171   7.2500   NaN        S      Mr         1
# 1      0   PC 17599  71.2833   C85        C     Mrs         2

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style  type="text/css" >
# #T_ea17f_row0_col0{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_ea17f_row1_col0{
#             background-color:  #d8ec66;
#             color:  #000000;
#         }#T_ea17f_row2_col0{
#             background-color:  #40a066;
#             color:  #000000;
#         }#T_ea17f_row3_col0{
#             background-color:  #289366;
#             color:  #000000;
#         }#T_ea17f_row4_col0{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_ea17f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age_band</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ea17f_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_ea17f_row0_col0" class="data row0 col0" >382</td>
#             </tr>
#             <tr>
#                         <th id="T_ea17f_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_ea17f_row1_col0" class="data row1 col0" >325</td>
#             </tr>
#             <tr>
#                         <th id="T_ea17f_level0_row2" class="row_heading level0 row2" >0</th>
#                         <td id="T_ea17f_row2_col0" class="data row2 col0" >104</td>
#             </tr>
#             <tr>
#                         <th id="T_ea17f_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ea17f_row3_col0" class="data row3 col0" >69</td>
#             </tr>
#             <tr>
#                         <th id="T_ea17f_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ea17f_row4_col0" class="data row4 col0" >11</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Age_band', 'Survived', data=data, col='Pclass')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - Pclass와 상관없이 연령이 증가할수록 생존율이 감소하는 것을 알 수 있다.

# %% [markdown]
# ## Family_Size and Alone¶

# %%
data['Family_Size'] = 0
data['Family_Size'] = data['Parch'] + data['SibSp']
data['Alone'] = 0
data.loc[data.Family_Size == 0, 'Alone'] = 1

# %%
f, ax = plt.subplots(1, 2, figsize=(18,6))
sns.pointplot('Family_Size', 'Survived', data=data, ax=ax[0])
ax[0].set_title('Family_Size vs Survived')

sns.pointplot('Alone', 'Survived', data=data, ax=ax[1])
ax[1].set_title('Alone vs Survived')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Alone', 'Survived', data=data, hue='Sex', col='Pclass')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# - 혼자 탑승한 승객과 4명 이상의 가족의 승객의 생존율이 낮음.
# - Pcalss 3에서 혼자 탑승한 여성이 가족이 있는 경우보다 높은 생존율을 보임.

# %% [markdown]
# ## Fare_Range
# - pandas.qcut을 사용하여 연속형 변수인 Fare를 순서형 변수로 변환한다.
# - qcut은 설정된 bin의 개수에 따라 균등한 개수 혹은 범위로 값을 분할한다.

# %%
data['Fare_Range'] = pd.qcut(data['Fare'], 4)
data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_5dc42_row0_col0{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_5dc42_row1_col0{
#             background-color:  #b9dc66;
#             color:  #000000;
#         }#T_5dc42_row2_col0{
#             background-color:  #54aa66;
#             color:  #000000;
#         }#T_5dc42_row3_col0{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_5dc42_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Survived</th>    </tr>    <tr>        <th class="index_name level0" >Fare_Range</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5dc42_level0_row0" class="row_heading level0 row0" >(-0.001, 7.91]</th>
#                         <td id="T_5dc42_row0_col0" class="data row0 col0" >0.197309</td>
#             </tr>
#             <tr>
#                         <th id="T_5dc42_level0_row1" class="row_heading level0 row1" >(7.91, 14.454]</th>
#                         <td id="T_5dc42_row1_col0" class="data row1 col0" >0.303571</td>
#             </tr>
#             <tr>
#                         <th id="T_5dc42_level0_row2" class="row_heading level0 row2" >(14.454, 31.0]</th>
#                         <td id="T_5dc42_row2_col0" class="data row2 col0" >0.454955</td>
#             </tr>
#             <tr>
#                         <th id="T_5dc42_level0_row3" class="row_heading level0 row3" >(31.0, 512.329]</th>
#                         <td id="T_5dc42_row3_col0" class="data row3 col0" >0.581081</td>
#             </tr>
#     </tbody></table>

# %%
#각 범위를 라벨링하여 category로 만들기
data['Fare_cat'] = 0
data.loc[data['Fare'] <= 7.91, 'Fare_cat'] = 0
data.loc[(data['Fare'] > 7.91) & (data['Fare'] <= 14.454), 'Fare_cat'] = 1
data.loc[(data['Fare'] > 14.454) & (data['Fare'] <= 31), 'Fare_cat'] = 2
data.loc[(data['Fare'] > 31) & (data['Fare'] <= 513), 'Fare_cat'] = 3

# %%
sns.factorplot('Fare_cat', 'Survived', data=data, hue='Sex')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Converting String Values into Numeric

# %%
data['Sex'].replace(['male', 'female'], [0, 1], inplace=True)
data['Embarked'].replace(['S', 'C' ,'Q'], [0, 1, 2], inplace=True)
data['Initial'].replace(['Mr', 'Mrs', 'Miss', 'Master', 'Other'], [0, 1, 2, 3, 4], inplace=True)

# %% [markdown]
# ## Dropping UnNeeded Features
# - 불필요한 변수를 떨구고 다른 것으로 변수를 대체함.

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked  Initial  Age_band  Family_Size  \
# 0         A/5 21171   7.2500   NaN         0        0         1            1
# 1          PC 17599  71.2833   C85         1        1         2            1
# 2  STON/O2. 3101282   7.9250   NaN         0        2         1            0
# 3            113803  53.1000  C123         0        1         2            1
# 4            373450   8.0500   NaN         0        0         2            0
#
#    Alone       Fare_Range  Fare_cat
# 0      0   (-0.001, 7.91]         0
# 1      0  (31.0, 512.329]         3
# 2      1   (7.91, 14.454]         1
# 3      0  (31.0, 512.329]         3
# 4      1   (7.91, 14.454]         1

# %%
#불필요한 변수 떨구기
data.drop(['Name', 'Age', 'Ticket', 'Fare', 'Cabin', 'Fare_Range', 'PassengerId'], axis=1, inplace=True)

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=True, cmap='RdYlGn', linewidths=0.2)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
